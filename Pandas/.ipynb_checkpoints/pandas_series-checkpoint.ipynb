# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
list_s = [1,3,5.6,-0.3,"data science"]
print(list_s)
# Out:
# [1, 3, 5.6, -0.3, 'data science']

# %%
series1 = pd.Series(list_s)
print(series1)
# Out:
# 0               1
# 1               3
# 2             5.6
# 3            -0.3
# 4    data science
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.Series([1,3,6,8,4,9,3])
print(series2)
# Out:
# 0    1
# 1    3
# 2    6
# 3    8
# 4    4
# 5    9
# 6    3
# dtype: int64

# %%
series3 = pd.Series([1,3,6,8,4],index=['a','b','c','d','e'])
print(series3)
# Out:
# a    1
# b    3
# c    6
# d    8
# e    4
# dtype: int64

# %%
series3 = pd.Series([1,3,6,8,4],index=['a','b','c','d','e'],dtype=float)
print(series3)
# Out:
# a    1.0
# b    3.0
# c    6.0
# d    8.0
# e    4.0
# dtype: float64
